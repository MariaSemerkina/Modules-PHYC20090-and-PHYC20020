# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import integrate
from scipy.optimize import curve_fit
# %matplotlib inline
plt.rcParams.update({'font.size': 22})
plt.rcParams["figure.figsize"] = (15,10)

# %%
cur=np.array([2.5e-9,3e-9,4.5e-9,7.5e-9,25e-9,109e-9,462e-9,201e-8,815e-8,335e-7,147e-6,316e-6])

volt=np.array([.552,.650,.732,.75,.77,.79,.81,.83,.85,.87,.89,.9])

# %%
plt.plot(volt,np.log(cur))
plt.grid(True)
