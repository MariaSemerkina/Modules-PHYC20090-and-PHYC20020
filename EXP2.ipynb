# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

plt.rcParams.update({'font.size': 22})
plt.rcParams["figure.figsize"] = (15,10)

x = np.arange(20,102,2)
y= (68,124,142,126,128,120,111,122,149,153,166,177,185,240,186,159,142,141,146,157,184,158,127,163,
   155,142,158,181,140,206,197,177,197,186,210,186,177,189,209,260,218)

plt.grid(True)
plt.plot(x,y)
plt.xlabel('2'r'$\theta$''($^\circ$C)')
plt.ylabel('Count Rate(s)')
plt.title('Count Rate vs 2'r'$\theta$ at 30kV in a LiF Crystal')
# Out:
# Text(0.5, 1.0, 'Count Rate vs 2$\\theta$ at 30kV in a LiF Crystal')

# %%
x1 = np.arange(20,102,2)
y1 = (40,45,56,52,59,56,56,44,54,59,81,66,80,120,74,72,
   73,69,50,59,70,73,62,72,63,75,78,72,71,72,89,71,87,91,92,
   87,83,102,96,94,114)

plt.grid(True)
plt.plot(x1,y1)
plt.xlabel('2'r'$\theta$''($^\circ$C)')
plt.ylabel('Count Rate(s)')
plt.title('Count Rate vs 2'r'$\theta$ at 20kV in a LiF Crystal')
# Out:
# Text(0.5, 1.0, 'Count Rate vs 2$\\theta$ at 20kV in a LiF Crystal')

# %%
def fitfunc(x,m,c):
    return m*x+c

# %%
y2=(.208,.391,.695,.749,.342,.391,.643,.766)
x2=(1,1,2,2,3,3,4,4)

pars, cov = curve_fit(fitfunc,x2,y2)
plt.plot(x,fitfunc(x,*pars),'g-')
plt.grid(True)
plt.plot(x2,y2,'bo')
